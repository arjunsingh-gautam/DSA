# %% [markdown]
# # **<span style="color:orange">Selection Sort</span>**

# %% [markdown]
# ## **Selection Sort Implementation**

# %%
from typing import List
def selection_sort(arr:List[int])->List[int]:
    n=len(arr)
    for i in range(n):
        min_index=i
        
        for j in range(i+1,n):
            if arr[j]<arr[min_index]:
                min_index=j
        
        # swapping the min element to fixed position
        arr[i],arr[min_index]=arr[min_index],arr[i]
    return arr

# %%
# input checking
arr=[33,293,192,943,18,39,193,1]
print(f"Sorted Array:{selection_sort(arr)}")
# Out:
# Sorted Array:[1, 18, 33, 39, 192, 193, 293, 943]
