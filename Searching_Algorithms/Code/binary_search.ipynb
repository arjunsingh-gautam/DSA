# %% [markdown]
# # **<span style="color:orange">Binary Search</span>**

# %% [markdown]
# ## **Iterative Approach**

# %%
# Binary Search Iterative 
def binary_search(arr,target):
    low=0
    high=len(arr)-1
    while low<=high: # invariant
        mid=low+(high-low)//2
        if arr[mid]==target:
            return mid
        elif target<arr[mid]:
            high=mid-1
        else:
            low=mid+1
    
    return -1 # if not found

# %%
arr=[1,33,34,282,2902,9191]
target=34

index=binary_search(arr,target)
if index==-1:
    print(f"{target} not found in arr-{arr}")
else:
    print(f"{target} found at index={index} in arr-{arr}")
# Out:
# 34 found at index=2 in arr-[1, 33, 34, 282, 2902, 9191]

# %% [markdown]
# ## **Recursive Approach**

# %%
def binary_search_recursive(arr,low,high,target):
    if low>high:
        return -1
    
    mid=(low+high)//2
    if arr[mid]==target:
        return mid
    elif target<arr[mid]:
        return binary_search_recursive(arr,low,mid-1,target)
    else:
        return binary_search_recursive(arr,mid+1,high,target)

# %%
arr=[1,33,34,282,2902,9191]
target=282

index=binary_search_recursive(arr,0,len(arr)-1,target)
if index==-1:
    print(f"{target} not found in arr-{arr}")
else:
    print(f"{target} found at index={index} in arr-{arr}")
# Out:
# 282 found at index=3 in arr-[1, 33, 34, 282, 2902, 9191]
